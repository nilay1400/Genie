# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Pytorch in python can be accessed by Torch library
import torch
# Check current torch version
torch.__version__

# In case Nvidea Cuda available, this will give True as result else False
torch.cuda.is_available()

import torchvision
# transform is used to convert data into Tensor form with transformations
import torchvision.transforms as transforms

train_set = torchvision.datasets.MNIST(
root = './data',
train = True,
download = True,
transform = transforms.Compose([transforms.ToTensor()])
)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

trans = transforms.Compose([
    # To resize image
    transforms.Resize((32,32)),
    transforms.ToTensor(),
    # To normalize image
    transforms.Normalize((0.5,), (0.5,))
])

train_set = torchvision.datasets.MNIST(
root = './data',
train = True,
download = True,
transform = trans
)

test_set = torchvision.datasets.MNIST(
root = './data',
train = False,
download = True,
transform = trans
)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 14702114.01it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 438446.29it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 4180311.97it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 1925268.19it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data.dataloader import DataLoader

# this is one of Hyper parameter, but let's select given below value
batch_size = 512

from torchvision.utils import make_grid
# this will help us to create Grid of images

import torch.nn as nn
import torch.nn.functional as F

class LeNet5(nn.Module):

    def __init__(self, num_classes):

        super().__init__()

        self.num_classes = num_classes

        self.features = nn.Sequential(
            nn.Conv2d(1, 6, kernel_size = 5),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size = 2),
            nn.Conv2d(6, 16, kernel_size = 5),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size = 2)
        )

        self.classifier = nn.Sequential(
            nn.Linear(16*5*5, 120),
            nn.Tanh(),
            nn.Linear(120, 84),
            nn.Tanh(),
            nn.Linear(84, num_classes)
        )



    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        logit = self.classifier(x)
        return logit

def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device

    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl:
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

def accuracy(output, labels):
    _, preds = torch.max(output, dim = 1)

    return torch.sum(preds == labels).item() / len(preds)


device = get_default_device()
device

def eevaluate(model, loss_fn, val_dl, metric = None, device='cuda'):

    with torch.no_grad():

        results = [loss_batch(model, loss_fn, x, y, metric = metric) for x, y in val_dl]

        losses, nums, metrics = zip(*results)

        total = np.sum(nums)

        avg_loss = np.sum(np.multiply(losses, nums)) / total

        avg_metric = None

        if metric is not None:
            avg_metric = np.sum(np.multiply(metrics, nums)) / total

    return avg_loss, total, avg_metric

def loss_batch(model, loss_func, x, y, opt = None, metric = None):

    pred = model(x)

    loss = loss_func(pred, y)

    if opt is not None:

        loss.backward()
        opt.step()
        opt.zero_grad()

    metric_result = None

    if metric is not None:

        metric_result = metric(pred, y)

    return loss.item(), len(x), metric_result

# %%
# !pip install quanto
# Out:
# Requirement already satisfied: quanto in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: torch>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from quanto) (2.3.1+cu121)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from quanto) (1.11.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from quanto) (1.25.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from quanto) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->quanto) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.2.0->quanto) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.2.0->quanto) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.2.0->quanto) (1.3.0)

# %%
import quanto
model = torch.load('/content/qLeNet.pth', map_location=device)

# %%
test_loader = DeviceDataLoader(DataLoader(test_set, batch_size=256), device)
result = eevaluate(model, F.cross_entropy, test_loader, metric = accuracy)
result
Accuracy = result[2] * 100
Accuracy
loss = result[0]
print("Total Losses: {}, Accuracy: {}".format(loss, Accuracy))
# Out:
# Total Losses: 0.038432069937186314, Accuracy: 98.9

# %%
print(model)
# Out:
# LeNet5(
#   (features): Sequential(
#     (0): QConv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#     (1): Tanh()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): QConv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#     (4): Tanh()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): QLinear(in_features=400, out_features=120, bias=True)
#     (1): Tanh()
#     (2): QLinear(in_features=120, out_features=84, bias=True)
#     (3): Tanh()
#     (4): QLinear(in_features=84, out_features=10, bias=True)
#   )
# )

# %%
# !pip install deap
# Out:
# Collecting deap
#   Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deap) (1.25.2)
# Installing collected packages: deap
# Successfully installed deap-1.4.1

# %%
import random
import numpy as np
from deap import base, creator, tools, algorithms

# %%
model = model.to('cuda')
# Define the evaluation function
def evaluate(individual):
    # print("Evaluating individual:", individual)
    model_copy = torch.load('/content/qLeNet.pth')
    model_copy = model_copy.to('cuda')

###################################################################

    state_dict = model_copy.state_dict()
    for layer_name, weight_idx in individual:
        weight = state_dict[layer_name].view(-1).to('cuda')
        # print(weight)
        # weight[weight_idx] += 0.01  # Perturb the weight slightly
        bit_position = random.randint(0, 7)
        if bit_position == 7:
             if weight[weight_idx] == -127:
                 weight[weight_idx] = 0
             else:
                 weight[weight_idx] = weight[weight_idx] * -1
        else:
            weight[weight_idx] = weight[weight_idx] ^ (1 << bit_position)


    # Load the perturbed weights back into the model
    model_copy.load_state_dict(state_dict)

    # Evaluate the perturbed model on a validation set
    model_copy.eval()
    result = eevaluate(model_copy, F.cross_entropy, test_loader, metric = accuracy)
    Accuracy = result[2] * 100
    loss = result[0]


    # Return the loss as fitness (higher loss indicates more critical weight)
    return loss,

# Create the fitness and individual classes
creator.create("FitnessMax", base.Fitness, weights=(1.0,))  # Maximize the function
creator.create("Individual", list, fitness=creator.FitnessMax)

toolbox = base.Toolbox()

def custom_mutate(individual, indpb):
    print("Before mutation:", individual)
    for i in range(len(individual)):
        if random.random() < indpb:
            layer, index = individual[i]
            new_index = random.randint(0, num_weights_per_layer[layer] - 1)
            individual[i] = (layer, new_index)
    print("After mutation:", individual)
    return individual,

def custom_crossover(ind1, ind2):
    print("Before crossover:", ind1, ind2)
    tools.cxTwoPoint(ind1, ind2)
    print("After crossover:", ind1, ind2)
    return ind1, ind2


# Attribute generator: (layer, index) pair
layer_names = [name for name in model.state_dict().keys() if 'weight._data' in name]
num_weights_per_layer = {name: model.state_dict()[name].numel() for name in layer_names}
def random_weight():
    layer = random.choice(layer_names)
    index = random.randint(0, num_weights_per_layer[layer] - 1)
    # print(layer,index)
    return (layer, index)

# Structure initializers
toolbox.register("individual", tools.initRepeat, creator.Individual, random_weight, n=5)  # Each individual perturbs 5 weights
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# Register the genetic operators
toolbox.register("mutate", custom_mutate, indpb=0.2)
toolbox.register("mate", custom_crossover)
toolbox.register("select", tools.selTournament, tournsize=3)
toolbox.register("evaluate", evaluate)

# %%
from deap import tools, base, creator, algorithms

def eaSimpleWithDebugging(population, toolbox, cxpb, mutpb, ngen, stats=None,
                          halloffame=None, verbose=__debug__):
    logbook = tools.Logbook()
    logbook.header = ['gen', 'nevals'] + (stats.fields if stats else [])

    # Evaluate the individuals with an invalid fitness
    invalid_ind = [ind for ind in population if not ind.fitness.valid]
    fitnesses = map(toolbox.evaluate, invalid_ind)
    for ind, fit in zip(invalid_ind, fitnesses):
        ind.fitness.values = fit
    if halloffame is not None:
        halloffame.update(population)
    record = stats.compile(population) if stats else {}
    logbook.record(gen=0, nevals=len(invalid_ind), **record)
    if verbose:
        print(logbook.stream)

    # Begin the generational process
    for gen in range(1, ngen + 1):
        print(f"Generation {gen}")

        # Select the next generation individuals
        offspring = toolbox.select(population, len(population))
        offspring = list(map(toolbox.clone, offspring))

        # Apply crossover and mutation on the offspring
        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < cxpb:
                print(f"Before mate: {child1}, {child2}")
                toolbox.mate(child1, child2)
                print(f"After mate: {child1}, {child2}")
                del child1.fitness.values
                del child2.fitness.values

        for mutant in offspring:
            if random.random() < mutpb:
                print(f"Before mutate: {mutant}")
                toolbox.mutate(mutant)
                print(f"After mutate: {mutant}")
                del mutant.fitness.values

        # Evaluate the individuals with an invalid fitness
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit

        # Update the hall of fame with the generated individuals
        if halloffame is not None:
            halloffame.update(offspring)

        # Replace the current population by the offspring
        population[:] = offspring

        # Append the current generation statistics to the logbook
        record = stats.compile(population) if stats else {}
        logbook.record(gen=gen, nevals=len(invalid_ind), **record)
        if verbose:
            print(logbook.stream)

    return population, logbook


def main():
    random.seed(42)

    # Create an initial population of 100 individuals
    population = toolbox.population(n=100)

    # Define statistics to keep track of the progress
    stats = tools.Statistics(lambda ind: ind.fitness.values[0])  # Extract the first element of the fitness tuple
    stats.register("avg", np.mean)
    stats.register("min", min)
    stats.register("max", max)

    # Hall of Fame to keep the best individual
    hof = tools.HallOfFame(1)

    # Run the genetic algorithm
    population, logbook = eaSimpleWithDebugging(population, toolbox, cxpb=0.5, mutpb=0.2, ngen=40,
                                                stats=stats, halloffame=hof, verbose=True)

    # Print the best individual
    print("Best individual is: ", hof[0])
    print("Fitness: ", hof[0].fitness.values[0])

if __name__ == "__main__":
    main()
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# After mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 54), ('features.0.weight._data', 59)]
# After mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 54), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 9337), ('features.3.weight._data', 1240), ('features.0.weight._data', 113), ('features.0.weight._data', 75)]
# Before mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 9337), ('features.3.weight._data', 1240), ('features.0.weight._data', 113), ('features.0.weight._data', 75)]
# After mutation: [('classifier.2.weight._data', 5966), ('classifier.2.weight._data', 9337), ('features.3.weight._data', 1240), ('features.0.weight._data', 113), ('features.0.weight._data', 75)]
# After mutate: [('classifier.2.weight._data', 5966), ('classifier.2.weight._data', 9337), ('features.3.weight._data', 1240), ('features.0.weight._data', 113), ('features.0.weight._data', 75)]
# Before mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# After mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 8209), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# After mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 8209), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 86), ('features.0.weight._data', 29)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 86), ('features.0.weight._data', 29)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6223), ('classifier.4.weight._data', 66), ('features.0.weight._data', 86), ('features.0.weight._data', 29)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6223), ('classifier.4.weight._data', 66), ('features.0.weight._data', 86), ('features.0.weight._data', 29)]
# Before mutate: [('classifier.4.weight._data', 501), ('classifier.2.weight._data', 9337), ('classifier.4.weight._data', 412), ('features.3.weight._data', 1741), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 501), ('classifier.2.weight._data', 9337), ('classifier.4.weight._data', 412), ('features.3.weight._data', 1741), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 501), ('classifier.2.weight._data', 9065), ('classifier.4.weight._data', 412), ('features.3.weight._data', 1741), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 501), ('classifier.2.weight._data', 9065), ('classifier.4.weight._data', 412), ('features.3.weight._data', 1741), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 68)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 68)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 11), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 11), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1196), ('classifier.4.weight._data', 119), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1196), ('classifier.4.weight._data', 119), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 90)]
# Before mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 90)]
# After mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 110), ('features.0.weight._data', 90)]
# After mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 110), ('features.0.weight._data', 90)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 9337), ('features.3.weight._data', 1240), ('features.0.weight._data', 113), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 9337), ('features.3.weight._data', 1240), ('features.0.weight._data', 113), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 9337), ('features.3.weight._data', 1868), ('features.0.weight._data', 113), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 9337), ('features.3.weight._data', 1868), ('features.0.weight._data', 113), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('features.3.weight._data', 947), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('features.3.weight._data', 947), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('features.3.weight._data', 26), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('features.3.weight._data', 26), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 442), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 453), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 442), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 453), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 237), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 237), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 40), ('features.0.weight._data', 101)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 40), ('features.0.weight._data', 101)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('features.0.weight._data', 28), ('features.0.weight._data', 38), ('features.0.weight._data', 86), ('features.0.weight._data', 141)]
# Before mutation: [('classifier.4.weight._data', 370), ('features.0.weight._data', 28), ('features.0.weight._data', 38), ('features.0.weight._data', 86), ('features.0.weight._data', 141)]
# After mutation: [('classifier.4.weight._data', 370), ('features.0.weight._data', 28), ('features.0.weight._data', 38), ('features.0.weight._data', 86), ('features.0.weight._data', 141)]
# After mutate: [('classifier.4.weight._data', 370), ('features.0.weight._data', 28), ('features.0.weight._data', 38), ('features.0.weight._data', 86), ('features.0.weight._data', 141)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# 13 	54    	0.0454318	0.0377073	0.0737908
# Generation 14
# Before mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 277), ('features.0.weight._data', 28), ('features.0.weight._data', 118), ('features.0.weight._data', 86), ('features.0.weight._data', 5)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 277), ('features.0.weight._data', 28), ('features.0.weight._data', 118), ('features.0.weight._data', 86), ('features.0.weight._data', 5)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 118), ('features.0.weight._data', 86), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 277), ('features.0.weight._data', 28), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 5)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 118), ('features.0.weight._data', 86), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 277), ('features.0.weight._data', 28), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 5)]
# Before mate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# Before mate: [('features.0.weight._data', 35), ('features.3.weight._data', 947), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('classifier.2.weight._data', 6678)], [('features.0.weight._data', 35), ('features.3.weight._data', 947), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('classifier.2.weight._data', 6678)]
# Before crossover: [('features.0.weight._data', 35), ('features.3.weight._data', 947), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('classifier.2.weight._data', 6678)] [('features.0.weight._data', 35), ('features.3.weight._data', 947), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('classifier.2.weight._data', 6678)]
# After crossover: [('features.0.weight._data', 35), ('features.3.weight._data', 947), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('classifier.2.weight._data', 6678)] [('features.0.weight._data', 35), ('features.3.weight._data', 947), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('classifier.2.weight._data', 6678)]
# After mate: [('features.0.weight._data', 35), ('features.3.weight._data', 947), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('classifier.2.weight._data', 6678)], [('features.0.weight._data', 35), ('features.3.weight._data', 947), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('classifier.2.weight._data', 6678)]
# Before mate: [('features.0.weight._data', 35), ('features.3.weight._data', 947), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('classifier.2.weight._data', 6678)], [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 9337), ('features.0.weight._data', 104), ('features.0.weight._data', 98), ('features.0.weight._data', 90)]
# Before crossover: [('features.0.weight._data', 35), ('features.3.weight._data', 947), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('classifier.2.weight._data', 6678)] [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 9337), ('features.0.weight._data', 104), ('features.0.weight._data', 98), ('features.0.weight._data', 90)]
# After crossover: [('features.0.weight._data', 35), ('classifier.2.weight._data', 9337), ('features.0.weight._data', 104), ('features.0.weight._data', 86), ('classifier.2.weight._data', 6678)] [('classifier.2.weight._data', 8479), ('features.3.weight._data', 947), ('features.3.weight._data', 920), ('features.0.weight._data', 98), ('features.0.weight._data', 90)]
# After mate: [('features.0.weight._data', 35), ('classifier.2.weight._data', 9337), ('features.0.weight._data', 104), ('features.0.weight._data', 86), ('classifier.2.weight._data', 6678)], [('classifier.2.weight._data', 8479), ('features.3.weight._data', 947), ('features.3.weight._data', 920), ('features.0.weight._data', 98), ('features.0.weight._data', 90)]
# Before mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)] [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)], [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.0.weight._data', 86), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.0.weight._data', 86), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# Before mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After crossover: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('classifier.4.weight._data', 382), ('features.0.weight._data', 86), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.3.weight._data', 920), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('classifier.4.weight._data', 382), ('features.0.weight._data', 86), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.3.weight._data', 920), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 7814), ('features.0.weight._data', 104), ('features.0.weight._data', 98), ('features.0.weight._data', 75)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 7814), ('features.0.weight._data', 104), ('features.0.weight._data', 98), ('features.0.weight._data', 75)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After crossover: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 7814), ('features.0.weight._data', 104), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 98), ('features.0.weight._data', 75)]
# After mate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 7814), ('features.0.weight._data', 104), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 98), ('features.0.weight._data', 75)]
# Before mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 136), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 136), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After crossover: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 136), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 136), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# Before mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.3.weight._data', 1741), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.3.weight._data', 1741), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After crossover: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.3.weight._data', 1741), ('features.0.weight._data', 59)]
# After mate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.3.weight._data', 1741), ('features.0.weight._data', 59)]
# Before mate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# After mutation: [('classifier.2.weight._data', 9797), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 87)]
# After mutate: [('classifier.2.weight._data', 9797), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 87)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.3.weight._data', 1185), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 561), ('features.0.weight._data', 70), ('features.0.weight._data', 57)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 561), ('features.0.weight._data', 70), ('features.0.weight._data', 57)]
# Before mutate: [('classifier.4.weight._data', 370), ('features.0.weight._data', 28), ('features.0.weight._data', 38), ('features.0.weight._data', 76), ('features.0.weight._data', 29)]
# Before mutation: [('classifier.4.weight._data', 370), ('features.0.weight._data', 28), ('features.0.weight._data', 38), ('features.0.weight._data', 76), ('features.0.weight._data', 29)]
# After mutation: [('classifier.4.weight._data', 370), ('features.0.weight._data', 123), ('features.0.weight._data', 38), ('features.0.weight._data', 76), ('features.0.weight._data', 29)]
# After mutate: [('classifier.4.weight._data', 370), ('features.0.weight._data', 123), ('features.0.weight._data', 38), ('features.0.weight._data', 76), ('features.0.weight._data', 29)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 129)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 129)]
# Before mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# After mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# After mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.2.weight._data', 4636), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 2000), ('features.0.weight._data', 86), ('features.0.weight._data', 141)]
# Before mutation: [('classifier.2.weight._data', 4636), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 2000), ('features.0.weight._data', 86), ('features.0.weight._data', 141)]
# After mutation: [('classifier.2.weight._data', 4636), ('classifier.2.weight._data', 7347), ('features.3.weight._data', 2000), ('features.0.weight._data', 88), ('features.0.weight._data', 141)]
# After mutate: [('classifier.2.weight._data', 4636), ('classifier.2.weight._data', 7347), ('features.3.weight._data', 2000), ('features.0.weight._data', 88), ('features.0.weight._data', 141)]
# Before mutate: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.0.weight._data', 101), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.4.weight._data', 196), ('features.0.weight._data', 11), ('features.0.weight._data', 101), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 7814), ('features.0.weight._data', 104), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 7814), ('features.0.weight._data', 104), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 7814), ('features.0.weight._data', 104), ('features.0.weight._data', 13), ('features.0.weight._data', 59)]
# After mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 7814), ('features.0.weight._data', 104), ('features.0.weight._data', 13), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# After mutation: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# After mutate: [('classifier.2.weight._data', 8479), ('classifier.2.weight._data', 1982), ('features.3.weight._data', 920), ('features.0.weight._data', 86), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('classifier.4.weight._data', 382), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# ...
# Before mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# Before mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After crossover: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)] [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After mate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)], [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 56)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 56)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 62)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 62)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 31), ('features.0.weight._data', 41), ('features.0.weight._data', 62)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 31), ('features.0.weight._data', 41), ('features.0.weight._data', 62)]
# Before mutate: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 29), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 29), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 29), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 29), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 702), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 702), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 5603), ('features.0.weight._data', 77), ('features.0.weight._data', 111), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 5603), ('features.0.weight._data', 77), ('features.0.weight._data', 111), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 88), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 88), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 88), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 88), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6797), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6797), ('features.0.weight._data', 77), ('features.0.weight._data', 81), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 8912), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 65), ('classifier.2.weight._data', 8912), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 520), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 90), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 520), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 90), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 197), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 197), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 41), ('features.0.weight._data', 59)]
# Before mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# Before mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 77), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After mutation: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 31), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# After mutate: [('classifier.4.weight._data', 370), ('classifier.2.weight._data', 6182), ('features.0.weight._data', 31), ('features.0.weight._data', 58), ('features.0.weight._data', 59)]
# 40 	60    	0.0593119	0.0382329	0.122184
# Best individual is:  [('classifier.2.weight._data', 9431), ('features.0.weight._data', 28), ('features.0.weight._data', 38), ('features.0.weight._data', 76), ('features.0.weight._data', 29)]
# Fitness:  0.19178607535883785
